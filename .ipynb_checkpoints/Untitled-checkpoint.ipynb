# %%
from sagemaker.huggingface.model import HuggingFaceModel
from sagemaker.serverless import ServerlessInferenceConfig

# %%
s3_location = "s3://bert-base-portuguese-cased/model.tar.gz"

# %%
from sagemaker.huggingface.model import HuggingFaceModel

iam_role = "arn:aws:iam::506568066138:role/bert-portuguese-cased"

sess = sagemaker.Session()

# create Hugging Face Model Class
huggingface_model = HuggingFaceModel(
   #env=hub,
   model_data=s3_location,       # path to your model and script
   role=iam_role,                # iam role with permissions to create an Endpoint
   transformers_version="4.12",  # transformers version used
   pytorch_version="1.9",        # pytorch version used
   py_version='py38',            # python version used
   sagemaker_session=sess,
)

serverless_config = ServerlessInferenceConfig(
    memory_size_in_mb=3072, max_concurrency=1,
)

# deploy the endpoint endpoint
predictor = huggingface_model.deploy(
    serverless_inference_config=serverless_config
#     initial_instance_count=1,
#     instance_type="ml.g4dn.xlarge"
    )
# Out:
# ------------!

# %%
data = {
    "inputs": [
        "Eai rapaziada, tudo de boa? Eu to feliz hoje",
        "Olá amigos, como vocês estão? bão demais, fala ai",
        "Bom dia a todos! Espero que tenham um ótimo dia.",
        "Boa tarde, pessoal! Alguém tem alguma novidade para compartilhar?",
    ] * 25
}


print(len(data["inputs"]))
# Out:
# 100

# %%
import time

start_time = time.time()
res = predictor.predict(data=data)
print(time.time()  - start_time)
print(res)
# Out:
# 1.8572053909301758
# {'vectors': [[0.0048615518026053905, -0.010232356376945972, 0.010639305226504803, -0.030199596658349037, 0.10045356303453445, 0.014770900830626488, -0.021027030423283577, -0.03932158648967743, 0.04096277058124542, -0.006628199014812708, 0.01779383048415184, 0.0156715027987957, 0.024013908579945564, -0.023351402953267097, -0.001886758953332901, 0.0172143392264843, 0.01370060071349144, 0.013522936031222343, 0.04053100571036339, -0.004083061590790749, 0.005905301310122013, 0.028904873877763748, 0.029485099017620087, -0.027584142982959747, -0.00908668339252472, 0.07123582810163498, 0.021759407594799995, 0.009194309823215008, 0.024279866367578506, -0.06890596449375153, 0.02724144421517849, 0.04868793115019798, -0.06288499385118484, 0.01385573111474514, 0.0585414282977581, -0.010951454751193523, 0.014031030237674713, -0.001257778494618833, 0.011369976215064526, -0.024561632424592972, 0.014192827045917511, -0.003908087965101004, -0.06392650306224823, -0.03497689589858055, -0.0010375729762017727, 0.0184083953499794, 0.01932707242667675, 0.04031135514378548, -0.08492843806743622, -0.03908201679587364, -0.002208204474300146, -0.00044947280548512936, -0.0610046461224556, 0.05487928166985512, 0.034638166427612305, -0.040618445724248886, 0.02728387713432312, -0.005680773872882128, 0.013670525513589382, -